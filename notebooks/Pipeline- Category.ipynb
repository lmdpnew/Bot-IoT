# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from sklearn.model_selection import train_test_split
from yellowbrick.classifier import ROCAUC

# Load multi-class classification dataset
from deepforest import CascadeForestClassifier


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression, SGDClassifier
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import roc_auc_score

# %%
# Load the dataset and split into train/test splits

# df = pd.read_csv('479.csv',sep=",") 
# del df['Unnamed: 0']

df=pd.read_csv('UNSW_2018_IoT_Botnet_Final_10_Best.csv',sep=";")  
del df['Unnamed: 0']
df.head()
# Out:
#    pkSeqID proto            saddr  sport            daddr dport  seq  \
# 0        1   tcp  192.168.100.147  49960    192.168.100.7    80    9
# 1        2   arp    192.168.100.7     -1  192.168.100.147    -1   10
# 2        3   tcp  192.168.100.147  49962    192.168.100.7    80   11
# 3        4   tcp  192.168.100.147  49964    192.168.100.7    80   12
# 4        5   tcp  192.168.100.147  49966    192.168.100.7    80   13
#
#      stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0  0.068909                 75  0.000000             1  0.068909
# 1  0.000000                  2  0.000131             2  0.000131
# 2  0.064494                 75  0.000000             1  0.064494
# 3  0.064189                 75  0.000000             1  0.064189
# 4  0.063887                 75  0.000000             1  0.063887
#
#    N_IN_Conn_P_DstIP      drate     srate       max  attack category  \
# 0                 96  14.511893  0.566862  0.137818       1      DoS
# 1                  1   0.000000  0.000000  0.000131       1      DoS
# 2                 96  15.505319  0.567549  0.128988       1      DoS
# 3                 96  15.578993  0.567570  0.128378       1      DoS
# 4                 96  15.652637  0.567630  0.127774       1      DoS
#
#   subcategory
# 0        HTTP
# 1        HTTP
# 2        HTTP
# 3        HTTP
# 4        HTTP

# %%
# 'attack','category','subcategory'
ten_best_features = df[['seq','stddev','N_IN_Conn_P_SrcIP', 'min', 'state_number', 'mean', 'N_IN_Conn_P_DstIP',
       'drate', 'srate', 'max','category']]

# %%
pd.value_counts(df.category)
# Out:
# DDoS              1926624
# DoS               1650260
# Reconnaissance      91082
# Normal                477
# Theft                  79
# Name: category, dtype: int64

# %%
classes = list(ten_best_features['category'].unique()) 
classes
# Out:
# ['DoS', 'DDoS', 'Normal', 'Reconnaissance', 'Theft']

# %%
labels = ['seq','stddev','N_IN_Conn_P_SrcIP', 'min', 'state_number', 'mean', 'N_IN_Conn_P_DstIP',
       'drate', 'srate', 'max']

# %%
# Load the dataset and split into train/test splits

ten_best_features = ten_best_features.values

y = ten_best_features[:,10]
X = ten_best_features[:,0:10]

# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=42)

# %% [markdown]
# # ROC AUC

# %%
from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.classifier import precision_recall_curve
from yellowbrick.model_selection import FeatureImportances

# %%
models = [
    ExtraTreesClassifier(n_estimators=100),
    RandomForestClassifier(n_estimators=100),
    SGDClassifier(),
    CascadeForestClassifier() 
]

for model in models:
     
    # Instaniate the classification model and visualizer
    print("--------------------------------------------")
    print("ROCAUC")
    print("--------------------------------------------")
    visualizer = ROCAUC(model, classes=classes)
    visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
    visualizer.score(X_test, y_test)        # Evaluate the model on the test data
    visualizer.show()                       # Finalize and render the figure
    #visualizer
    
    print("--------------------------------------------")
    print("confusion_matrix classification_report")
    print("--------------------------------------------")
    
    predicted = visualizer.predict(X_test)
    print("accuracy_score:",format(accuracy_score(y_test, predicted)), model)
    print(confusion_matrix(y_test,predicted))
    print('\n')
    print(classification_report(y_test,predicted))
    
    print("--------------------------------------------")
    print("recall_curve_viz")
    print("--------------------------------------------")
    
    # recall_curve_viz : Create the visualizer, fit, score, and show it
    recall_curve_viz = precision_recall_curve(model, X_train, y_train, X_test, y_test)
    recall_curve_viz.show()

    print("--------------------------------------------")
    print("PrecisionRecallCurve")
    print("--------------------------------------------")
    
    # PrecisionRecallCurve : Create the visualizer, fit, score, and show it 
    viz = PrecisionRecallCurve(model,classes=classes,iso_f1_curves=True,per_class=True,micro=False)
    viz.fit(X_train, y_train)
    viz.score(X_test, y_test)
    viz.show()
# Out:
# --------------------------------------------
# ROCAUC
# --------------------------------------------
# --------------------------------------------
# confusion_matrix classification_report
# --------------------------------------------
# accuracy_score: 0.999960928875106 ExtraTreesClassifier()
# [[577968      5      0      1      0]
#  [    16 495235      1      0      0]
#  [     1      1    136      3      0]
#  [     3      4      3  27156      0]
#  [     0      1      2      2     19]]
#
#
#                 precision    recall  f1-score   support
#
#           DDoS       1.00      1.00      1.00    577974
#            DoS       1.00      1.00      1.00    495252
#         Normal       0.96      0.96      0.96       141
# Reconnaissance       1.00      1.00      1.00     27166
#          Theft       1.00      0.79      0.88        24
#
#       accuracy                           1.00   1100557
#      macro avg       0.99      0.95      0.97   1100557
#   weighted avg       1.00      1.00      1.00   1100557
#
# --------------------------------------------
# recall_curve_viz
# --------------------------------------------
# --------------------------------------------
# PrecisionRecallCurve
# --------------------------------------------
# --------------------------------------------
# ROCAUC
# --------------------------------------------
# --------------------------------------------
# confusion_matrix classification_report
# --------------------------------------------
# accuracy_score: 0.9999700151832208 RandomForestClassifier()
# [[577969      4      0      1      0]
#  [    12 495238      2      0      0]
#  [     0      2    136      3      0]
#  [     0      2      1  27163      0]
#  [     0      0      2      4     18]]
#
#
#                 precision    recall  f1-score   support
#
#           DDoS       1.00      1.00      1.00    577974
#            DoS       1.00      1.00      1.00    495252
#         Normal       0.96      0.96      0.96       141
# Reconnaissance       1.00      1.00      1.00     27166
#          Theft       1.00      0.75      0.86        24
#
#       accuracy                           1.00   1100557
#      macro avg       0.99      0.94      0.96   1100557
#   weighted avg       1.00      1.00      1.00   1100557
#
# --------------------------------------------
# recall_curve_viz
# --------------------------------------------
# --------------------------------------------
# PrecisionRecallCurve
# --------------------------------------------
# --------------------------------------------
# ROCAUC
# --------------------------------------------
# --------------------------------------------
# confusion_matrix classification_report
# --------------------------------------------
# accuracy_score: 0.5273357036482436 SGDClassifier()
# [[577085    372      0    517      0]
#  [491914   1596      1   1741      0]
#  [    46     87      3      5      0]
#  [ 22438   2782    267   1679      0]
#  [     0     22      0      2      0]]
#
#
#                 precision    recall  f1-score   support
#
#           DDoS       0.53      1.00      0.69    577974
#            DoS       0.33      0.00      0.01    495252
#         Normal       0.01      0.02      0.01       141
# Reconnaissance       0.43      0.06      0.11     27166
#          Theft       0.00      0.00      0.00        24
#
#       accuracy                           0.53   1100557
#      macro avg       0.26      0.22      0.16   1100557
#   weighted avg       0.44      0.53      0.37   1100557
#
# --------------------------------------------
# recall_curve_viz
# --------------------------------------------
# --------------------------------------------
# PrecisionRecallCurve
# --------------------------------------------
# --------------------------------------------
# ROCAUC
# --------------------------------------------
# [2023-01-12 00:01:45.364] Start to fit the model:
# [2023-01-12 00:01:45.366] Fitting cascade layer = 0
# [2023-01-12 00:16:55.293] layer = 0  | Val Acc = 99.972 % | Elapsed = 909.928 s
# [2023-01-12 00:16:57.421] Fitting cascade layer = 1
# [2023-01-12 00:27:23.315] layer = 1  | Val Acc = 99.971 % | Elapsed = 625.893 s
# [2023-01-12 00:27:23.315] Early stopping counter: 1 out of 2
# [2023-01-12 00:27:25.633] Fitting cascade layer = 2
# [2023-01-12 00:38:05.343] layer = 2  | Val Acc = 99.970 % | Elapsed = 639.711 s
# [2023-01-12 00:38:05.343] Early stopping counter: 2 out of 2
# [2023-01-12 00:38:05.343] Handling early stopping
# [2023-01-12 00:38:05.375] The optimal number of layers: 1
# [2023-01-12 00:38:09.086] Start to evalute the model:
# [2023-01-12 00:38:09.540] Evaluating cascade layer = 0
# [2023-01-12 00:39:24.425] Start to evalute the model:
# [2023-01-12 00:39:24.849] Evaluating cascade layer = 0
# --------------------------------------------
# confusion_matrix classification_report
# --------------------------------------------
# [2023-01-12 00:40:49.170] Start to evalute the model:
# [2023-01-12 00:40:49.658] Evaluating cascade layer = 0
# accuracy_score: 0.9997010604630201 CascadeForestClassifier()
# [[577734    240      0      0      0]
#  [    78 495173      1      0      0]
#  [     1      1    137      2      0]
#  [     0      0      2  27164      0]
#  [     0      0      2      2     20]]
#
#
#                 precision    recall  f1-score   support
#
#           DDoS       1.00      1.00      1.00    577974
#            DoS       1.00      1.00      1.00    495252
#         Normal       0.96      0.97      0.97       141
# Reconnaissance       1.00      1.00      1.00     27166
#          Theft       1.00      0.83      0.91        24
#
#       accuracy                           1.00   1100557
#      macro avg       0.99      0.96      0.98   1100557
#   weighted avg       1.00      1.00      1.00   1100557
#
# --------------------------------------------
# recall_curve_viz
# --------------------------------------------
# [2023-01-12 00:42:58.835] Start to fit the model:
# [2023-01-12 00:42:58.835] Fitting cascade layer = 0
# [2023-01-12 00:57:39.557] layer = 0  | Val Acc = 99.969 % | Elapsed = 880.722 s
# [2023-01-12 00:57:40.808] Fitting cascade layer = 1
# [2023-01-12 01:03:55.178] layer = 1  | Val Acc = 99.970 % | Elapsed = 374.370 s
# [2023-01-12 01:03:55.178] Early stopping counter: 1 out of 2
# [2023-01-12 01:03:56.433] Fitting cascade layer = 2
# [2023-01-12 01:14:19.761] layer = 2  | Val Acc = 99.994 % | Elapsed = 623.328 s
# [2023-01-12 01:14:20.914] Fitting cascade layer = 3
# [2023-01-12 01:26:28.602] layer = 3  | Val Acc = 99.995 % | Elapsed = 727.688 s
# [2023-01-12 01:26:28.602] Early stopping counter: 1 out of 2
# [2023-01-12 01:26:29.598] Fitting cascade layer = 4
# [2023-01-12 01:38:44.337] layer = 4  | Val Acc = 99.994 % | Elapsed = 734.739 s
# [2023-01-12 01:38:44.337] Early stopping counter: 2 out of 2
# [2023-01-12 01:38:44.337] Handling early stopping
# [2023-01-12 01:38:44.347] The optimal number of layers: 3
# [2023-01-12 01:38:49.823] Start to fit the model:
# [2023-01-12 01:38:49.823] Fitting cascade layer = 0
# [2023-01-12 01:53:16.424] layer = 0  | Val Acc = 99.968 % | Elapsed = 866.601 s
# [2023-01-12 01:53:17.646] Fitting cascade layer = 1
# [2023-01-12 01:58:26.973] layer = 1  | Val Acc = 99.967 % | Elapsed = 309.327 s
# [2023-01-12 01:58:26.973] Early stopping counter: 1 out of 2
# [2023-01-12 01:58:28.267] Fitting cascade layer = 2
# [2023-01-12 02:07:15.247] layer = 2  | Val Acc = 99.992 % | Elapsed = 526.980 s
# [2023-01-12 02:07:16.602] Fitting cascade layer = 3
# [2023-01-12 02:18:01.126] layer = 3  | Val Acc = 99.992 % | Elapsed = 644.523 s
# [2023-01-12 02:18:01.126] Early stopping counter: 1 out of 2
# [2023-01-12 02:18:02.328] Fitting cascade layer = 4
# [2023-01-12 11:28:06.732] layer = 4  | Val Acc = 99.992 % | Elapsed = 33004.405 s
# [2023-01-12 11:28:06.732] Early stopping counter: 2 out of 2
# [2023-01-12 11:28:06.732] Handling early stopping
# [2023-01-12 11:28:06.748] The optimal number of layers: 3
# [2023-01-12 11:28:12.546] Start to fit the model:
# [2023-01-12 11:28:12.546] Fitting cascade layer = 0
# [2023-01-12 11:35:59.967] layer = 0  | Val Acc = 99.999 % | Elapsed = 467.421 s
# [2023-01-12 11:36:00.682] Fitting cascade layer = 1
# [2023-01-12 11:40:48.279] layer = 1  | Val Acc = 99.999 % | Elapsed = 287.597 s
# [2023-01-12 11:40:48.280] Early stopping counter: 1 out of 2
# [2023-01-12 11:40:48.697] Fitting cascade layer = 2
# [2023-01-12 11:45:52.098] layer = 2  | Val Acc = 99.999 % | Elapsed = 303.400 s
# [2023-01-12 11:45:52.098] Early stopping counter: 2 out of 2
# [2023-01-12 11:45:52.098] Handling early stopping
# [2023-01-12 11:45:52.107] The optimal number of layers: 1
# [2023-01-12 11:45:57.422] Start to fit the model:
# [2023-01-12 11:45:57.422] Fitting cascade layer = 0
# [2023-01-12 11:55:56.715] layer = 0  | Val Acc = 99.999 % | Elapsed = 599.293 s
# [2023-01-12 11:55:57.413] Fitting cascade layer = 1
# [2023-01-12 12:01:33.159] layer = 1  | Val Acc = 99.999 % | Elapsed = 335.746 s
# [2023-01-12 12:01:33.159] Early stopping counter: 1 out of 2
# [2023-01-12 12:01:33.717] Fitting cascade layer = 2
# [2023-01-12 12:06:35.721] layer = 2  | Val Acc = 99.999 % | Elapsed = 302.005 s
# [2023-01-12 12:06:35.722] Early stopping counter: 2 out of 2
# [2023-01-12 12:06:35.722] Handling early stopping
# [2023-01-12 12:06:35.741] The optimal number of layers: 1
# [2023-01-12 12:06:41.113] Start to fit the model:
# [2023-01-12 12:06:41.113] Fitting cascade layer = 0
# [2023-01-12 12:10:27.828] layer = 0  | Val Acc = 100.000 % | Elapsed = 226.715 s
# [2023-01-12 12:10:28.312] Fitting cascade layer = 1
# [2023-01-12 12:15:35.710] layer = 1  | Val Acc = 100.000 % | Elapsed = 307.398 s
# [2023-01-12 12:15:35.710] Early stopping counter: 1 out of 2
# [2023-01-12 12:15:36.099] Fitting cascade layer = 2
# [2023-01-12 12:20:03.531] layer = 2  | Val Acc = 100.000 % | Elapsed = 267.432 s
# [2023-01-12 12:20:03.531] Early stopping counter: 2 out of 2
# [2023-01-12 12:20:03.531] Handling early stopping
# [2023-01-12 12:20:03.544] The optimal number of layers: 1
# [2023-01-12 12:20:06.259] Start to evalute the model:
# [2023-01-12 12:20:06.653] Evaluating cascade layer = 0
# [2023-01-12 12:21:02.857] Evaluating cascade layer = 1
# [2023-01-12 12:21:22.867] Evaluating cascade layer = 2
# [2023-01-12 12:21:54.172] Start to evalute the model:
# [2023-01-12 12:21:54.559] Evaluating cascade layer = 0
# [2023-01-12 12:22:50.500] Evaluating cascade layer = 1
# [2023-01-12 12:23:09.076] Evaluating cascade layer = 2
# [2023-01-12 12:23:36.618] Start to evalute the model:
# [2023-01-12 12:23:36.991] Evaluating cascade layer = 0
# [2023-01-12 12:23:57.735] Start to evalute the model:
# [2023-01-12 12:23:58.240] Evaluating cascade layer = 0
# [2023-01-12 12:24:27.868] Start to evalute the model:
# [2023-01-12 12:24:28.391] Evaluating cascade layer = 0
# [2023-01-12 12:24:43.535] Start to evalute the model:
# [2023-01-12 12:24:43.903] Evaluating cascade layer = 0
# [2023-01-12 12:25:40.324] Evaluating cascade layer = 1
# [2023-01-12 12:26:00.274] Evaluating cascade layer = 2
# [2023-01-12 12:26:30.178] Start to evalute the model:
# [2023-01-12 12:26:30.578] Evaluating cascade layer = 0
# [2023-01-12 12:27:26.299] Evaluating cascade layer = 1
# [2023-01-12 12:27:44.347] Evaluating cascade layer = 2
# [2023-01-12 12:28:11.787] Start to evalute the model:
# [2023-01-12 12:28:12.272] Evaluating cascade layer = 0
# [2023-01-12 12:28:33.622] Start to evalute the model:
# [2023-01-12 12:28:34.124] Evaluating cascade layer = 0
# [2023-01-12 12:29:03.577] Start to evalute the model:
# [2023-01-12 12:29:04.001] Evaluating cascade layer = 0
# --------------------------------------------
# PrecisionRecallCurve
# --------------------------------------------
# [2023-01-12 12:29:31.688] Start to fit the model:
# [2023-01-12 12:29:31.688] Fitting cascade layer = 0
# [2023-01-12 12:43:23.350] layer = 0  | Val Acc = 99.968 % | Elapsed = 831.662 s
# [2023-01-12 12:43:24.642] Fitting cascade layer = 1
# [2023-01-12 12:49:09.492] layer = 1  | Val Acc = 99.968 % | Elapsed = 344.850 s
# [2023-01-12 12:49:09.492] Early stopping counter: 1 out of 2
# [2023-01-12 12:49:10.675] Fitting cascade layer = 2
# [2023-01-12 12:55:54.831] layer = 2  | Val Acc = 99.968 % | Elapsed = 404.156 s
# [2023-01-12 12:55:54.831] Early stopping counter: 2 out of 2
# [2023-01-12 12:55:54.831] Handling early stopping
# [2023-01-12 12:55:54.847] The optimal number of layers: 1
# [2023-01-12 12:56:00.207] Start to fit the model:
# [2023-01-12 12:56:00.207] Fitting cascade layer = 0
# [2023-01-12 13:10:26.769] layer = 0  | Val Acc = 99.960 % | Elapsed = 866.562 s
# [2023-01-12 13:10:28.100] Fitting cascade layer = 1
# [2023-01-12 13:17:40.228] layer = 1  | Val Acc = 99.968 % | Elapsed = 432.128 s
# [2023-01-12 13:17:41.403] Fitting cascade layer = 2
# [2023-01-12 13:23:41.357] layer = 2  | Val Acc = 99.966 % | Elapsed = 359.954 s
# [2023-01-12 13:23:41.357] Early stopping counter: 1 out of 2
# [2023-01-12 13:23:42.438] Fitting cascade layer = 3
# [2023-01-12 13:29:48.942] layer = 3  | Val Acc = 99.966 % | Elapsed = 366.504 s
# [2023-01-12 13:29:48.942] Early stopping counter: 2 out of 2
# [2023-01-12 13:29:48.942] Handling early stopping
# [2023-01-12 13:29:48.961] The optimal number of layers: 2
# [2023-01-12 13:29:55.605] Start to fit the model:
# [2023-01-12 13:29:55.605] Fitting cascade layer = 0
# [2023-01-12 13:38:24.206] layer = 0  | Val Acc = 99.999 % | Elapsed = 508.601 s
# [2023-01-12 13:38:25.356] Fitting cascade layer = 1
# [2023-01-12 13:43:41.572] layer = 1  | Val Acc = 99.999 % | Elapsed = 316.216 s
# [2023-01-12 13:43:41.572] Early stopping counter: 1 out of 2
# [2023-01-12 13:43:42.105] Fitting cascade layer = 2
# [2023-01-12 13:49:30.190] layer = 2  | Val Acc = 99.999 % | Elapsed = 348.085 s
# [2023-01-12 13:49:30.190] Early stopping counter: 2 out of 2
# [2023-01-12 13:49:30.190] Handling early stopping
# [2023-01-12 13:49:30.190] The optimal number of layers: 1
# [2023-01-12 13:49:35.867] Start to fit the model:
# [2023-01-12 13:49:35.867] Fitting cascade layer = 0
# [2023-01-12 13:59:42.725] layer = 0  | Val Acc = 99.999 % | Elapsed = 606.858 s
# [2023-01-12 13:59:43.433] Fitting cascade layer = 1
# [2023-01-12 14:05:46.836] layer = 1  | Val Acc = 99.999 % | Elapsed = 363.404 s
# [2023-01-12 14:05:46.836] Early stopping counter: 1 out of 2
# [2023-01-12 14:05:47.546] Fitting cascade layer = 2
# [2023-01-12 14:11:07.104] layer = 2  | Val Acc = 99.999 % | Elapsed = 319.557 s
# [2023-01-12 14:11:07.104] Early stopping counter: 2 out of 2
# [2023-01-12 14:11:07.104] Handling early stopping
# [2023-01-12 14:11:07.120] The optimal number of layers: 1
# [2023-01-12 14:11:12.734] Start to fit the model:
# [2023-01-12 14:11:12.734] Fitting cascade layer = 0
# [2023-01-12 14:15:00.438] layer = 0  | Val Acc = 100.000 % | Elapsed = 227.704 s
# [2023-01-12 14:15:00.938] Fitting cascade layer = 1
# [2023-01-12 14:20:12.853] layer = 1  | Val Acc = 100.000 % | Elapsed = 311.915 s
# [2023-01-12 14:20:12.853] Early stopping counter: 1 out of 2
# [2023-01-12 14:20:13.400] Fitting cascade layer = 2
# [2023-01-12 14:25:28.294] layer = 2  | Val Acc = 100.000 % | Elapsed = 314.895 s
# [2023-01-12 14:25:28.294] Early stopping counter: 2 out of 2
# [2023-01-12 14:25:28.294] Handling early stopping
# [2023-01-12 14:25:28.310] The optimal number of layers: 1
# [2023-01-12 14:25:31.735] Start to evalute the model:
# [2023-01-12 14:25:32.158] Evaluating cascade layer = 0
# [2023-01-12 14:26:33.919] Start to evalute the model:
# [2023-01-12 14:26:34.279] Evaluating cascade layer = 0
# [2023-01-12 14:27:33.245] Evaluating cascade layer = 1
# [2023-01-12 14:27:58.028] Start to evalute the model:
# [2023-01-12 14:27:58.530] Evaluating cascade layer = 0
# [2023-01-12 14:28:20.501] Start to evalute the model:
# [2023-01-12 14:28:21.066] Evaluating cascade layer = 0
# [2023-01-12 14:28:50.859] Start to evalute the model:
# [2023-01-12 14:28:51.314] Evaluating cascade layer = 0
# [2023-01-12 14:29:06.989] Start to evalute the model:
# [2023-01-12 14:29:07.475] Evaluating cascade layer = 0
# [2023-01-12 14:30:07.502] Start to evalute the model:
# [2023-01-12 14:30:08.036] Evaluating cascade layer = 0
# [2023-01-12 14:31:06.482] Evaluating cascade layer = 1
# [2023-01-12 14:31:30.666] Start to evalute the model:
# [2023-01-12 14:31:31.106] Evaluating cascade layer = 0
# [2023-01-12 14:31:52.757] Start to evalute the model:
# [2023-01-12 14:31:53.353] Evaluating cascade layer = 0
# [2023-01-12 14:32:24.795] Start to evalute the model:
# [2023-01-12 14:32:25.202] Evaluating cascade layer = 0
